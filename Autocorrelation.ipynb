# %%
import pandas as pd
import numpy as np
import statsmodels.tsa.api as smt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv",index_col="Date")

# %%
data.index = pd.to_datetime(data.index)

# %%
print(data.shape)
# Out:
# (3650, 1)

# %%
data.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
Calculate Autocovariance of Temp column
# Out:
#   File "C:\Users\Manoj\AppData\Local\Temp\ipykernel_10736\1256247405.py", line 1
#     Calculate Autocovariance of Temp column
#               ^
# SyntaxError: invalid syntax

# %%
smt.stattools.acovf(data[:20])
# Out:
# array([ 1.010510e+01,  4.408355e+00, -6.342900e-01, -1.495935e+00,
#        -1.316180e+00, -1.443475e+00, -4.288200e-01,  7.155850e-01,
#         1.831690e+00,  1.372950e-01, -2.870950e+00, -3.624195e+00,
#        -1.485090e+00, -5.879850e-01, -4.358000e-02,  8.315750e-01,
#         6.112800e-01,  6.655350e-01,  5.390000e-03, -3.287550e-01])

# %%
lags = [10,50,100,200,500,1500,3000]
for l in lags:
    titles = "'Autocorrelation with lags "+ str(l)
    smt.graphics.plot_acf(data,lags=l,alpha=0.05,title=titles)

# %%
lags = [10,50,100,200]
for l in lags:
    titles = "Partial Autocorrelation with lags "+ str(l)
    smt.graphics.plot_acf(data,lags=l,alpha=0.05,title=titles)
